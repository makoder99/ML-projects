# %%
#importing the Matplotlib,the visual artist

import matplotlib.pyplot as plt

# %%
#importing the Counter which we will wills use the divide the data later on
from collections import Counter

# %%
#calling on our statistical mate, the cuddly pandas
import pandas as pd

# %%
#wtf! Stealing corey Shafer's code again!

df=pd.read_csv("https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Matplotlib/02-BarCharts/data.csv")

# %%
#let's take a look at the life of geeks, oh well no surprise

df
# Out:
#        Responder_id                                LanguagesWorkedWith
# 0                 1                    HTML/CSS;Java;JavaScript;Python
# 1                 2                                C++;HTML/CSS;Python
# 2                 3                                           HTML/CSS
# 3                 4                                C;C++;C#;Python;SQL
# 4                 5        C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# ...             ...                                                ...
# 87564         88182                           HTML/CSS;Java;JavaScript
# 87565         88212                         HTML/CSS;JavaScript;Python
# 87566         88282  Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 87567         88377                      HTML/CSS;JavaScript;Other(s):
# 87568         88863  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
#
# [87569 rows x 2 columns]

# %%
#the usual, divinding the datas into two list

ids=df['Responder_id']
languages=df['LanguagesWorkedWith']
languages
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 87564                             HTML/CSS;Java;JavaScript
# 87565                           HTML/CSS;JavaScript;Python
# 87566    Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;W...
# 87567                        HTML/CSS;JavaScript;Other(s):
# 87568    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguagesWorkedWith, Length: 87569, dtype: object

# %%
#I swear i know counter works. We have created it. The i in the loop goes on and on, adds the values in into counter. The split helps on seprating the langugae names

languages_counter=Counter()

for i in languages:
    languages_counter.update(i.split(';'))

# %%
#We need two lists which act as labels and values for our delicious pie. Used a for loop so that it adds the values into it

language=[]
popularity=[]

for d in languages_counter.most_common(5):
    language.append(d[0])
    popularity.append(d[1])
language
# Out:
# ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']

# %%
#umm the aroma is here let's take a look at it
plt.pie(popularity,labels=language,)
# Out:
# ([<matplotlib.patches.Wedge at 0x2226f05d6a0>,
# ...
#  [Text(0.9843226122588631, 0.491028507314889, 'JavaScript'),
#   Text(0.23139477667444028, 1.0753866548027207, 'HTML/CSS'),
#   Text(-0.6146994255065557, 0.9122196096784537, 'SQL'),
#   Text(-1.0436117179515185, 0.34767022040186357, 'Python'),
#   Text(-1.0674624570178632, -0.26556336881691117, 'Java'),
#   Text(-0.7862856172007463, -0.7692560875178315, 'Bash/Shell/PowerShell'),
#   Text(-0.36127463681325483, -1.0389805757546438, 'C#'),
#   Text(0.06271087631612919, -1.098210975173561, 'PHP'),
#   Text(0.4256878521252104, -1.0142927844330873, 'C++'),
#   Text(0.7107154038569522, -0.8395734719013277, 'TypeScript'),
#   Text(0.9184117306636805, -0.6054088643052259, 'C'),
#   Text(1.021473009537878, -0.408157923830508, 'Other(s):'),
#   Text(1.062753092216688, -0.2838236512059353, 'Ruby'),
#   Text(1.088068122601307, -0.16157896081751277, 'Go'),
#   Text(1.0988576487863024, -0.050118536529305716, 'Assembly')])

# %%
# Out:
# ([<matplotlib.patches.Wedge at 0x2226f238bb0>,
# ...
#  [Text(-0.7837501906172629, 0.7718391274789094, 'JavaScript'),
#   Text(-0.7987513829484706, -0.7563043225037827, 'HTML/CSS'),
#   Text(0.5906400253912186, -0.9279786422142812, 'SQL'),
#   Text(1.2905323543121674, 0.15660856449598942, 'Python'),
#   Text(0.508929586614865, 0.9751875080557701, 'Java')],
#  [Text(-0.42750010397305244, 0.4210031604430415, '25%'),
#   Text(-0.4356825725173476, -0.4125296304566087, '24%'),
#   Text(0.3221672865770283, -0.5061701684805169, '20%'),
#   Text(0.7941737564997954, 0.09637450122830118, '16%'),
#   Text(0.27759795633538087, 0.5319204589395109, '15%')])

# %%
#Lets's take a final look at our pie! Hope you liked it. DO let me know if you find it difficult or erm.... funny explode helped python to shine amonst all


plt.style.use('seaborn-talk')

plt.pie(popularity,labels=language,wedgeprops={'edgecolor':'black'},autopct='%1.0f%%',explode=[0,0,0,0.2,0],startangle=90,shadow=True)
plt.title("Programming langauge Popularity Pie Chart")

plt.tight_layout

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Lets garnish it with something like a frame 
plt.style.use('seaborn-talk')
plt.pie(popularity,labels=language,wedgeprops={'edgecolor':'black'},autopct='%1.0f%%',explode=[0,0,0,0.2,0],startangle=90,shadow=True,counterclock=True,frame=True)
plt.title("Programming langauge Popularity Pie Chart")

plt.tight_layout

plt.show


#Well it does is not helping much Let's go back
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#let's just take it

plt.style.use('seaborn-talk')
plt.pie(popularity,labels=language,wedgeprops={'edgecolor':'black'},autopct='%1.0f%%',explode=[0,0,0,0.2,0],startangle=90,shadow=True)
plt.title("Programming langauge Popularity Pie Chart")

plt.tight_layout

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
''''saving it as a souvenir , can send you but you probably think I am nerd already :)'''

plt.savefig('pie_plot.pdf')
